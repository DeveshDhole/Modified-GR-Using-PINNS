# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,1,1000)
f = 1/4

sine = np.sin(2*np.pi*f*x) + np.random.normal(scale=0.1, size=len(x))
# sine = x**5
plt.plot(x,sine)

poly = np.polyfit(x, sine, deg=5)

fig, ax = plt.subplots()
ax.plot(x,sine, label='data')
ax.plot(x,np.polyval(poly, x), label='fit')
ax.legend()

# %%
poly
# Out:
# array([ 1.00000000e+00, -7.72326241e-15,  8.46352205e-15, -4.50415058e-15,
#         1.28508331e-15, -1.60179325e-16])

# %%
x = np.linspace(0,1,1000)
f = 1/4

sine = np.sin(2*np.pi*f*x) + np.random.normal(scale=0.1, size=len(x))
# sine = x**5
plt.plot(x,sine)

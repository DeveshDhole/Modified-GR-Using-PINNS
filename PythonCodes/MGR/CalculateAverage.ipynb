# %%
with open('full.txt', 'w') as f:
    for line in full:
        f.write(f"{line}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open('full.txt', 'w') as f:
# ----> 2     for line in full:
#       3         f.write(f"{line}\n")
#
# NameError: name 'full' is not defined

# %%
import json

with open('full_1.txt', 'r') as file:
    array_list = json.load(file)

print(array_list)
# Out:
# [[0.42508548, 0.21354293, 0.48288469, -0.56412219, -0.4666745, 0.07595025], [0.00609656222, 2.66952196, -5.25764837, 6.13022121, -4.36292423, 0.981403982], [0.11665416, 2.23006922, -4.71755375, 6.09753673, -4.71459944, 1.15463982], [0.18644927, 1.96637345, -4.46773751, 6.33628483, -5.24211864, 1.38789427], [0.45883891, 0.18938933, 0.28231264, -0.01102854, -1.01919938, 0.26376499], [0.47275766, 0.18760169, 0.27159919, 0.01606076, -1.07421139, 0.28542791], [0.47516046, 0.21480569, 0.22895147, -0.00722759, -0.98942614, 0.22988741], [0.4841687, 0.23987887, 0.18361867, -0.03993302, -0.87651435, 0.14645084], [0.46107156, 0.18579021, 0.23700344, 0.10849022, -1.1047061, 0.27130154], [0.43377816, 0.22923762, 0.16800454, 0.03066072, -0.71800562, 0.00753281], [0.38425162, 0.23858516, 0.13947234, 0.02465425, -0.39916231, -0.22658376], [0.16321873, 0.71576975, -0.58264345, -1.4524854, 5.20620316, -4.19744359], [0.04393267, 0.11494258, -0.02704504, 0.01898697, 1.37301114, -0.85118502], [0.09515206
# ...

# %%
type(array_list)
# Out:
# list

# %%
import numpy
m = numpy.array(array_list)
print(m.shape)
# print(m.shape[0])
# print(m.shape[1])
a = m.shape[0]
b = m.shape[1]
# Out:
# (42, 6)

# %%
out = []
for j in range(b):
    Sum = 0.0
    for i in range(a):
        Sum += m[i][j]
    avg = Sum/a
    out.append(avg)

# %%
print(out)
# Out:
# [0.10790360498857146, 0.5320187618577619, -0.9086795274523809, -3.0401073881666667, 16.314560151880954, -10.726008774714288]

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
